# %%
# %matplotlib inline
import pandas as pd
import matplotlib as ml
import quandl
import requests

# %%
quandl.ApiConfig.api_key = "FzzdzYpLoyfcMBT8zjJV"

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
mydata = quandl.get("HKEX/01288") # example of a quandl call for an individual stock
print(mydata)
# Out:
#             Nominal Price  Net Change  Change (%)   Bid   Ask  P/E(x)  High  \
# Date
# 2014-02-21           3.35        0.03       0.888  3.34  3.35    6.00  3.43
# 2014-02-24           3.29        0.06       1.791  3.28  3.29    5.89  3.34
# 2014-02-25           3.29        0.00       0.000  3.29  3.30    5.89  3.33
# 2014-02-26           3.29        0.00       0.000  3.29  3.30    5.89  3.32
# 2014-02-27           3.36        0.07       2.128  3.35  3.37    6.02  3.37
# 2014-02-28           3.29        0.07       2.083  3.29  3.30    5.89  3.40
# 2014-03-05           3.22        0.04       1.227  3.22  3.23    5.77  3.29
# 2014-03-06           3.21        0.01       0.311  3.21  3.22    5.75  3.24
# 2014-03-07           3.20        0.01       0.312  3.20  3.21    5.73  3.25
# 2014-03-10           3.17        0.03       0.938  3.15  3.16    5.68  3.18
# 2014-03-11           3.16        0.01       0.315  3.16  3.17    5.66  3.22
# ...

# %%
mydata_two = quandl.get("HKEX/01288.1") # call only the nominal price column for a stock and plot
mydata_two.plot()

# %%
stocks = pd.DataFrame.from_csv('stocks.csv', index_col=None) # Universe of dual-listed stocks and their quandl calls
stocks
# Out:
#     A_Shares      A_Share_Call  H_Shares H_Share_Call H_Share_Call_Price  \
# 0     601288  YAHOO/SZ_ 601288      1288   HKEX/01288     "HKEX/01288.1"
# 1     601111   YAHOO/SZ_601111       753   HKEX/00753     "HKEX/00753.1"
# 2        898   YAHOO/SZ_000898       347   HKEX/00347     "HKEX/00347.1"
# 3     600585   YAHOO/SZ_600585       914   HKEX/00914     "HKEX/00914.1"
# 4     600332   YAHOO/SZ_600332       874   HKEX/00874     "HKEX/00874.1"
# 5     601988   YAHOO/SZ_601988      3988   HKEX/03988     "HKEX/03988.1"
# 6     601328   YAHOO/SZ_601328      3328   HKEX/03328     "HKEX/03328.1"
# 7     601992   YAHOO/SZ_601992      2009   HKEX/02009     "HKEX/02009.1"
# 8       2594   YAHOO/SZ_002594      1211   HKEX/01211     "HKEX/01211.1"
# 9     601939   YAHOO/SZ_601939       939   HKEX/00939     "HKEX/00939.1"
# 10    601818   YAHOO/SZ_601818      6818   HKEX/06818     "HKEX/06818.1"
# 11    601600   YAHOO/SZ_601600      2600   HKEX/02600     "HKEX/02600.1"
# ...

# %%
# A while loop that performs quandl calls using the H_Share_Call_Price column
for item in stocks.H_Share_Call_Price:
    mydata_three = quandl.get(item)
print(mydata_three)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-fa1e54a3ccbe> in <module>()
#       1 # A while loop that performs quandl calls using the H_Share_Call_Price column
#       2 for item in stocks.H_Share_Call_Price:
# ----> 3     mydata_three = quandl.get(item)
#       4 print(mydata_three)
#
# //anaconda/lib/python3.5/site-packages/quandl/get.py in get(dataset, **kwargs)
#      43     # Unicode String
#      44     if isinstance(dataset, string_types):
# ---> 45         dataset_args = _parse_dataset_code(dataset)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
#
# //anaconda/lib/python3.5/site-packages/quandl/get.py in _parse_dataset_code(dataset)
#      69     dataset_temp = dataset.split('.')
#      70     if not dataset_temp[1].isdigit():
# ...
